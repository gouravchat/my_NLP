# %% [markdown]
# <a href="https://colab.research.google.com/github/Goro-python/my_NLP/blob/next_dev/SNLI_benchmark_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!ls

# %%
#!git clone https://github.com/Smerity/keras_snli.git

# %%
#!ls

# %%
#!ls keras_snli

# %%
#!python3 keras_snli/snli_rnn.py

# %%
#!wget http://nlp.stanford.edu/data/glove.840B.300d.zip
#
# !ls
# Out:
# glove.840B.300d.zip    keras_snli  sample_data	snli_1.0.zip
# glove.840B.300d.zip.1  __MACOSX    snli_1.0

# %%
#!unzip -q glove.840B.300d.zip.1

# %%
# !ls
# Out:
# glove.840B.300d.txt  glove.840B.300d.zip.1  __MACOSX	 snli_1.0
# glove.840B.300d.zip  keras_snli		    sample_data  snli_1.0.zip

# %%
#!wget https://nlp.stanford.edu/projects/snli/snli_1.0.zip

# %%
# !wget -q snli_1.0.zip

# %%
# !unzip -q snli_1.0.zip
# Out:
# replace snli_1.0/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# getting data 
from __future__ import print_function
from functools import reduce
import json
import os
import re
import tarfile
import tempfile

import numpy as np
np.random.seed(1337)  # for reproducibility


import keras
import keras.backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import merge, recurrent, Dense, Input, Dropout, TimeDistributed,concatenate
from keras.layers.embeddings import Embedding
from keras.layers.normalization import BatchNormalization
from keras.layers.wrappers import Bidirectional
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.regularizers import l2
from keras.utils import np_utils

# %%
def extract_tokens_from_binary_parse(parse):
    return parse.replace('(', ' ').replace(')', ' ').replace('-LRB-', '(').replace('-RRB-', ')').split()

def yield_examples(fn, skip_no_majority=True, limit=None):
  for i, line in enumerate(open(fn)):
    if limit and i > limit:
      break
    data = json.loads(line)
    label = data['gold_label']
    s1 = ' '.join(extract_tokens_from_binary_parse(data['sentence1_binary_parse']))
    s2 = ' '.join(extract_tokens_from_binary_parse(data['sentence2_binary_parse']))
    if skip_no_majority and label == '-':
      continue
    yield (label, s1, s2)

def get_data(fn, limit=None):
  raw_data = list(yield_examples(fn=fn, limit=limit))
  left = [s1 for _, s1, s2 in raw_data]
  right = [s2 for _, s1, s2 in raw_data]
  print(max(len(x.split()) for x in left))
  print(max(len(x.split()) for x in right))

  LABELS = {'contradiction': 0, 'neutral': 1, 'entailment': 2}
  Y = np.array([LABELS[l] for l, s1, s2 in raw_data])
  Y = np_utils.to_categorical(Y, len(LABELS))

  return left, right, Y

training = get_data('snli_1.0/snli_1.0_train.jsonl')
validation = get_data('snli_1.0/snli_1.0_dev.jsonl')
test = get_data('snli_1.0/snli_1.0_test.jsonl')
# Out:
# 82
# 62
# 59
# 55
# 57
# 30

# %%
tokenizer = Tokenizer(lower=False, filters='')
tokenizer.fit_on_texts(training[0] + training[1])

# Lowest index from the tokenizer is 1 - we need to include 0 in our vocab count
VOCAB = len(tokenizer.word_counts) + 1
LABELS = {'contradiction': 0, 'neutral': 1, 'entailment': 2}
#RNN = recurrent.LSTM
#RNN = lambda *args, **kwargs: Bidirectional(recurrent.LSTM(*args, **kwargs))
#RNN = recurrent.GRU
#RNN = lambda *args, **kwargs: Bidirectional(recurrent.GRU(*args, **kwargs))
# Summation of word embeddings
RNN = None
LAYERS = 1
USE_GLOVE = True
TRAIN_EMBED = False
EMBED_HIDDEN_SIZE = 300
SENT_HIDDEN_SIZE = 300
BATCH_SIZE = 512
PATIENCE = 4 # 8
MAX_EPOCHS = 42
MAX_LEN = 42
DP = 0.2
L2 = 4e-6
ACTIVATION = 'relu'
OPTIMIZER = 'rmsprop'
print('RNN / Embed / Sent = {}, {}, {}'.format(RNN, EMBED_HIDDEN_SIZE, SENT_HIDDEN_SIZE))
print('GloVe / Trainable Word Embeddings = {}, {}'.format(USE_GLOVE, TRAIN_EMBED))

to_seq = lambda X: pad_sequences(tokenizer.texts_to_sequences(X), maxlen=MAX_LEN)
prepare_data = lambda data: (to_seq(data[0]), to_seq(data[1]), data[2])

training = prepare_data(training)
validation = prepare_data(validation)
test = prepare_data(test)

print('Build model...')
print('Vocab size =', VOCAB)

GLOVE_STORE = 'precomputed_glove.weights'
if USE_GLOVE:
  if not os.path.exists(GLOVE_STORE + '.npy'):
    print('Computing GloVe')
  
    embeddings_index = {}
    f = open('glove.840B.300d.txt')
    for line in f:
      values = line.split(' ')
      word = values[0]
      coefs = np.asarray(values[1:], dtype='float32')
      embeddings_index[word] = coefs
    f.close()
    
    # prepare embedding matrix
    embedding_matrix = np.zeros((VOCAB, EMBED_HIDDEN_SIZE))
    for word, i in tokenizer.word_index.items():
      embedding_vector = embeddings_index.get(word)
      if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
      else:
        print('Missing from GloVe: {}'.format(word))
  
    np.save(GLOVE_STORE, embedding_matrix)

  print('Loading GloVe')
  embedding_matrix = np.load(GLOVE_STORE + '.npy')

  print('Total number of null word embeddings:')
  print(np.sum(np.sum(embedding_matrix, axis=1) == 0))

  embed = Embedding(VOCAB, EMBED_HIDDEN_SIZE, weights=[embedding_matrix], input_length=MAX_LEN, trainable=TRAIN_EMBED)
else:
  embed = Embedding(VOCAB, EMBED_HIDDEN_SIZE, input_length=MAX_LEN)
# Out:
# RNN / Embed / Sent = None, 300, 300
# GloVe / Trainable Word Embeddings = True, False
# Build model...
# Vocab size = 42391
# Computing GloVe
# Missing from GloVe: blond-hair
# Missing from GloVe: rollerskaters
# Missing from GloVe: surfboarder
# Missing from GloVe: Blond-haired
# Missing from GloVe: graffited
# Missing from GloVe: parasailer
# Missing from GloVe: blond-headed
# Missing from GloVe: boogieboard
# Missing from GloVe: turkers
# Missing from GloVe: casually-dressed
# Missing from GloVe: ggauged
# Missing from GloVe: brunette-haired
# Missing from GloVe: mini-race
# Missing from GloVe: RoadWork
# Missing from GloVe: waterskiis
# Missing from GloVe: green-shirted
# Missing from GloVe: rally-car
# Missing from GloVe: bvoy
# Missing from GloVe: rollerskater
# Missing from GloVe: med-evil
# Missing from GloVe: hoolahoops
# Missing from GloVe: window-washers
# Missing from GloVe: outstreached
# Missing from GloVe: large-brimmed
# Missing from GloVe: mid-throw
# Missing from GloVe: red-sleeved
# Missing from GloVe: white-helmeted
# Missing from GloVe: Violoncelli
# Missing from GloVe: yellow-belt
# Missing from GloVe: blue-roofed
# Missing from GloVe: re-inactors
# Missing from GloVe: 66197
# Missing from GloVe: unhappy-looking
# Missing from GloVe: phone-booths
# Missing from GloVe: white-rimmed
# Missing from GloVe: TheFaceShop
# Missing from GloVe: diveboard
# Missing from GloVe: taped-off
# Missing from GloVe: dress-shoes
# Missing from GloVe: Kuthhoop
# Missing from GloVe: roll-open
# Missing from GloVe: garage-type
# Missing from GloVe: wave-crashing
# Missing from GloVe: North-worst
# Missing from GloVe: rough-houses
# Missing from GloVe: Rottwieler
# Missing from GloVe: Pipe-fitters
# Missing from GloVe: Wolf-like
# Missing from GloVe: it.aa
# Missing from GloVe: clay-tiled
# Missing from GloVe: snowshovel
# Missing from GloVe: umbrella-ed
# Missing from GloVe: lightly-colored
# Missing from GloVe: sillhouetted
# Missing from GloVe: marble-looking
# Missing from GloVe: chidl
# Missing from GloVe: handstnad
# Missing from GloVe: face-height
# Missing from GloVe: zepra
# Missing from GloVe: C-U-B-S
# Missing from GloVe: leaf-lined
# Missing from GloVe: findersport
# Missing from GloVe: slightly-untidy
# Missing from GloVe: leave-like
# Missing from GloVe: river-rapids
# Missing from GloVe: vertically-striped
# Missing from GloVe: two-thumbs-up
# Missing from GloVe: coke-a-cola
# Missing from GloVe: wearubg
# Missing from GloVe: bread-butter-cheese-victory
# Missing from GloVe: blue-plaid
# Missing from GloVe: brighly
# Missing from GloVe: blue-shirts
# Missing from GloVe: green-shirts
# Missing from GloVe: bikina
# Missing from GloVe: saroog
# Missing from GloVe: partially-drunk
# Missing from GloVe: homemade-looking
# Missing from GloVe: cross-bone
# Missing from GloVe: long-lensed
# Missing from GloVe: dirt-still
# Missing from GloVe: streteched
# Missing from GloVe: Prave
# Missing from GloVe: steeply-angled
# Missing from GloVe: D'antan
# Missing from GloVe: authority-figure
# Missing from GloVe: flame-themed
# Missing from GloVe: rapels
# Missing from GloVe: futon-style
# Missing from GloVe: GIDDAY
# Missing from GloVe: native-looking
# Missing from GloVe: stheart
# Missing from GloVe: black-bound
# Missing from GloVe: SHOESHINE
# Missing from GloVe: scientific-looking
# Missing from GloVe: scatteredly
# Missing from GloVe: INHABITABLE
# Missing from GloVe: adeleide
# Missing from GloVe: obliverate
# Missing from GloVe: burbur
# Missing from GloVe: gray-tiled
# Missing from GloVe: ciff
# Missing from GloVe: formally-dressed
# Missing from GloVe: waterskies
# Missing from GloVe: parasurfer
# Missing from GloVe: Blond-hair
# Missing from GloVe: mid-twirl
# Missing from GloVe: mo-hawk
# Missing from GloVe: skateborder
# Missing from GloVe: parasurfing
# Missing from GloVe: wearign
# Missing from GloVe: ShoeGasm
# Missing from GloVe: para-glider
# Missing from GloVe: copper-rimmed
# Missing from GloVe: fore-ground
# Missing from GloVe: orange-sashed
# Missing from GloVe: Znocob
# Missing from GloVe: red-uniformed
# Missing from GloVe: motor-cross
# Missing from GloVe: ball-cap
# Missing from GloVe: pro-saw
# Missing from GloVe: brush-land
# Missing from GloVe: childing
# Missing from GloVe: snokel
# Missing from GloVe: Waterskier
# Missing from GloVe: donkey-drawn
# Missing from GloVe: mow-hawk
# Missing from GloVe: parasailors
# Missing from GloVe: bad-mitten
# Missing from GloVe: Miradore
# Missing from GloVe: Mandita
# Missing from GloVe: graffiti-laden
# Missing from GloVe: dirt-bikes
# Missing from GloVe: S.C.U.B.A.
# Missing from GloVe: handstanding
# Missing from GloVe: water-wings
# Missing from GloVe: PEOPLPE
# Missing from GloVe: hopskotch
# Missing from GloVe: Nobdoy
# Missing from GloVe: graffiti-filled
# Missing from GloVe: east-Asian
# Missing from GloVe: strange-shaped
# Missing from GloVe: jump-kick
# Missing from GloVe: cowboy-looking
# Missing from GloVe: crowd-lined
# Missing from GloVe: sky-view
# Missing from GloVe: bicycle-like
# Missing from GloVe: blue-checked
# Missing from GloVe: TubeLine
# Missing from GloVe: arts-style
# Missing from GloVe: fishemen
# Missing from GloVe: Budweiser-sponsored
# Missing from GloVe: dirtbikers
# Missing from GloVe: riverwater
# Missing from GloVe: red-vested
# Missing from GloVe: SXSWO
# Missing from GloVe: plaided
# Missing from GloVe: raft-type
# Missing from GloVe: Langostinos
# Missing from GloVe: semi-cloudy
# Missing from GloVe: outDoors
# Missing from GloVe: Zuccherberg
# Missing from GloVe: horizontally-striped
# Missing from GloVe: reflector-vest
# Missing from GloVe: Gelados
# Missing from GloVe: Coldtowne
# Missing from GloVe: drop-cloth
# Missing from GloVe: tractor-like
# Missing from GloVe: tan-skinned
# Missing from GloVe: mid-kick
# Missing from GloVe: graffiti-ridden
# Missing from GloVe: not-so-crowded
# Missing from GloVe: Maruga
# Missing from GloVe: Lyppens
# Missing from GloVe: avrovulcan.com
# Missing from GloVe: Dashnell
# Missing from GloVe: push-brooms
# Missing from GloVe: SPFD
# Missing from GloVe: otuside
# Missing from GloVe: Orhtophonie
# Missing from GloVe: Tye-dyed
# Missing from GloVe: amuseument
# Missing from GloVe: break-dances
# Missing from GloVe: makeup-ed
# Missing from GloVe: light-purple
# Missing from GloVe: paraglides
# Missing from GloVe: semi-crowded
# Missing from GloVe: acrouss
# Missing from GloVe: sailboarder
# Missing from GloVe: castanhas
# Missing from GloVe: brightly-dressed
# Missing from GloVe: footbride
# Missing from GloVe: AMBUC
# Missing from GloVe: trash-bag
# Missing from GloVe: hand-decorating
# Missing from GloVe: Salyo
# Missing from GloVe: middle-to-high-school-aged
# Missing from GloVe: game-boys
# Missing from GloVe: bicylist
# Missing from GloVe: Weimeraners
# Missing from GloVe: stonesign
# Missing from GloVe: Parasailer
# Missing from GloVe: Globe-Slicers
# Missing from GloVe: kiyaking
# Missing from GloVe: graffti
# Missing from GloVe: pedicycle
# Missing from GloVe: ELOIN
# Missing from GloVe: sandy-blonde
# Missing from GloVe: railgrind
# Missing from GloVe: MonsterBowl
# Missing from GloVe: para-gliders
# Missing from GloVe: outfir
# Missing from GloVe: water-wear
# Missing from GloVe: Casterol
# Missing from GloVe: fanny-pak
# Missing from GloVe: midjump
# Missing from GloVe: Rodderick
# Missing from GloVe: lionist
# Missing from GloVe: un-amused
# Missing from GloVe: belly-surfing
# Missing from GloVe: tychy
# Missing from GloVe: cart-load
# Missing from GloVe: motorcylist
# Missing from GloVe: shoeshiner
# Missing from GloVe: eplaying
# Missing from GloVe: port-a
# Missing from GloVe: mturkgrind
# Missing from GloVe: groupl
# Missing from GloVe: leaf-printed
# Missing from GloVe: sleeding
# Missing from GloVe: bicycle-mounted
# Missing from GloVe: ski-suit
# Missing from GloVe: mini-scooter
# Missing from GloVe: Geospec
# Missing from GloVe: GkickS
# Missing from GloVe: Pro-Saw
# Missing from GloVe: Thing-o-matic
# Missing from GloVe: swim-trunks
# Missing from GloVe: waterful
# Missing from GloVe: closer-to-shore
# Missing from GloVe: sprinkers
# Missing from GloVe: Goctawek
# Missing from GloVe: vac-cumming
# Missing from GloVe: hi-chair
# Missing from GloVe: Vaggi
# Missing from GloVe: clown-themed
# Missing from GloVe: patio-type
# Missing from GloVe: snow-angel
# Missing from GloVe: skeleton-themed
# Missing from GloVe: lillypads
# Missing from GloVe: heavily-packed
# Missing from GloVe: nose-holding
# Missing from GloVe: waveboarder
# Missing from GloVe: bike-riders
# Missing from GloVe: glass-doored
# Missing from GloVe: ganilla
# Missing from GloVe: smoke-pot
# Missing from GloVe: windsailing
# Missing from GloVe: pink-coated
# Missing from GloVe: dimmly
# Missing from GloVe: monoboard
# Missing from GloVe: railling
# Missing from GloVe: lightly-wooded
# Missing from GloVe: Eyrovia
# Missing from GloVe: non-blooming
# Missing from GloVe: yellow-suited
# Missing from GloVe: parasailor
# Missing from GloVe: towarn
# Missing from GloVe: windboarder
# Missing from GloVe: tan-bricked
# Missing from GloVe: Peoople
# Missing from GloVe: blue-jerseyed
# Missing from GloVe: Highschoolers
# Missing from GloVe: red-hatted
# Missing from GloVe: Davonik
# Missing from GloVe: Ovodafone
# Missing from GloVe: pin-wheels
# Missing from GloVe: red-handled
# Missing from GloVe: climbes
# Missing from GloVe: neck-wear
# Missing from GloVe: sitts
# Missing from GloVe: tangerine-colored
# Missing from GloVe: ball-thrower
# Missing from GloVe: Horse-riders
# Missing from GloVe: airwoman
# Missing from GloVe: tobaggons
# Missing from GloVe: ty-dye
# Missing from GloVe: YumYumBowls
# Missing from GloVe: upset-looking
# Missing from GloVe: DAHLAK
# Missing from GloVe: surf-skier
# Missing from GloVe: Buzzcock
# Missing from GloVe: Chorriada
# Missing from GloVe: armstand
# Missing from GloVe: Rollerskaters
# Missing from GloVe: skatebaord
# Missing from GloVe: fruitstand
# Missing from GloVe: skatboard
# Missing from GloVe: skaterboarder
# Missing from GloVe: climibing
# Missing from GloVe: white-hair
# Missing from GloVe: across-country
# Missing from GloVe: restrings
# Missing from GloVe: tandem-biking
# Missing from GloVe: snowboader
# Missing from GloVe: mostly-barren
# Missing from GloVe: snow-gear
# Missing from GloVe: shot-on-goal
# Missing from GloVe: warms-up
# Missing from GloVe: truck-full
# Missing from GloVe: aquestrian
# Missing from GloVe: performance3
# Missing from GloVe: stall-shops
# Missing from GloVe: folding-chairs
# Missing from GloVe: black-shirt
# Missing from GloVe: pink-like
# Missing from GloVe: pop-a-wheely
# Missing from GloVe: javelin-style
# Missing from GloVe: soocerball
# Missing from GloVe: Racedog
# Missing from GloVe: hiply
# Missing from GloVe: stomach-down
# Missing from GloVe: race-bibs
# Missing from GloVe: ax-throwing
# Missing from GloVe: briskly-flowing
# Missing from GloVe: GUARDANO
# Missing from GloVe: PAVITMENTO
# Missing from GloVe: bulk-wall
# Missing from GloVe: thin-metal
# Missing from GloVe: Ski-Doos
# Missing from GloVe: nicely-dressed
# Missing from GloVe: yellow-fenced
# Missing from GloVe: Bull-branded
# Missing from GloVe: mid-hockey
# Missing from GloVe: blurred-out
# Missing from GloVe: fur-line
# Missing from GloVe: chasseing
# Missing from GloVe: mid-punch
# Missing from GloVe: bting
# Missing from GloVe: desert-looking
# Missing from GloVe: backlegs
# Missing from GloVe: ski-divers
# Missing from GloVe: exercise-wheel
# Missing from GloVe: plywood-paneled
# Missing from GloVe: freesbies
# Missing from GloVe: SEMBLANCE
# Missing from GloVe: kimino
# Missing from GloVe: re-patching
# Missing from GloVe: seidwalk
# Missing from GloVe: beige-striped
# Missing from GloVe: button-p
# Missing from GloVe: concrete-sided
# Missing from GloVe: batter-in-training
# Missing from GloVe: shoeshines
# Missing from GloVe: pillow-fight
# Missing from GloVe: kayer
# Missing from GloVe: stone-filled
# Missing from GloVe: re-tarring
# Missing from GloVe: swaetshirt
# Missing from GloVe: objest
# Missing from GloVe: teal-haired
# Missing from GloVe: microphone-singing
# Missing from GloVe: canoe-type
# Missing from GloVe: city-themed
# Missing from GloVe: sit-atop
# Missing from GloVe: glass-blown
# Missing from GloVe: green-bodied
# Missing from GloVe: derssed
# Missing from GloVe: arm-exercising
# Missing from GloVe: jersay
# Missing from GloVe: clibing
# Missing from GloVe: hodling
# Missing from GloVe: zoomsystems
# Missing from GloVe: pie-filling
# Missing from GloVe: kakhis
# Missing from GloVe: graffiti-strewn
# Missing from GloVe: roller-blader
# Missing from GloVe: rocks.A
# Missing from GloVe: top-toe
# Missing from GloVe: arch-style
# Missing from GloVe: Brunette-haired
# Missing from GloVe: lute-guitar
# Missing from GloVe: Insulfoam
# Missing from GloVe: leaf-blow
# Missing from GloVe: wrist-guards
# Missing from GloVe: bubble-maker
# Missing from GloVe: darkly-lit
# Missing from GloVe: hand-paddles
# Missing from GloVe: almost-dried
# Missing from GloVe: DiPAOLA
# Missing from GloVe: STATIONNEMENT
# Missing from GloVe: DOTRE
# Missing from GloVe: yellow-grassed
# Missing from GloVe: smokey-hazed
# Missing from GloVe: swetashirts
# Missing from GloVe: rope-swinging
# Missing from GloVe: crowd.d
# Missing from GloVe: over-alls
# Missing from GloVe: spashes
# Missing from GloVe: stunt-leap
# Missing from GloVe: Gleati
# Missing from GloVe: Light-haired
# Missing from GloVe: siluettes
# Missing from GloVe: www.rouleur.cc
# Missing from GloVe: Genpac
# Missing from GloVe: Shirt-wearing
# Missing from GloVe: orange-vested
# Missing from GloVe: checker-like
# Missing from GloVe: flighht
# Missing from GloVe: jomps
# Missing from GloVe: sit-and-bounce
# Missing from GloVe: grunge-type
# Missing from GloVe: Caution-Children
# Missing from GloVe: sports-field
# Missing from GloVe: Doneley
# Missing from GloVe: Middle-Eastern-style
# Missing from GloVe: campflauge
# Missing from GloVe: fedora-adorned
# Missing from GloVe: dishdashas
# Missing from GloVe: rocket-themed
# Missing from GloVe: brightly-bannered
# Missing from GloVe: hangong
# Missing from GloVe: wetsuite
# Missing from GloVe: light-post
# Missing from GloVe: mosque-like
# Missing from GloVe: motorcrossing
# Missing from GloVe: mary-go-round
# Missing from GloVe: umbrella-shaded
# Missing from GloVe: partially-opened
# Missing from GloVe: genie-like
# Missing from GloVe: father-aged
# Missing from GloVe: survey-type
# Missing from GloVe: roller-skaters
# Missing from GloVe: warmly-dressed
# Missing from GloVe: flower-box
# Missing from GloVe: rangler
# Missing from GloVe: half-wrapped
# Missing from GloVe: petterned
# Missing from GloVe: nussle
# Missing from GloVe: Avai-brand
# Missing from GloVe: outcroping
# Missing from GloVe: snow-patched
# Missing from GloVe: roof-type
# Missing from GloVe: pick-ax
# Missing from GloVe: Apples-to-Apples
# Missing from GloVe: car-lined
# Missing from GloVe: young-lady
# Missing from GloVe: Matulog
# Missing from GloVe: sliiding
# Missing from GloVe: toerh
# Missing from GloVe: shirt-stained
# Missing from GloVe: baskers
# Missing from GloVe: passenager
# Missing from GloVe: dandylions
# Missing from GloVe: silohuetted
# Missing from GloVe: xylophonist
# Missing from GloVe: ramp-shaped
# Missing from GloVe: grooms-man
# Missing from GloVe: rock-bottomed
# Missing from GloVe: forest-lined
# Missing from GloVe: rockabilly-clad
# Missing from GloVe: business-formal
# Missing from GloVe: alarmedly
# Missing from GloVe: busily-decorated
# Missing from GloVe: fire-dancer
# Missing from GloVe: paraskier
# Missing from GloVe: OUVERT
# Missing from GloVe: sweatshir
# Missing from GloVe: ROADWORK
# Missing from GloVe: news-reporter
# Missing from GloVe: blue-vested
# Missing from GloVe: group-effort
# Missing from GloVe: ballroom-dancing
# Missing from GloVe: filmier
# Missing from GloVe: scarf-clad
# Missing from GloVe: hispanic-looking
# Missing from GloVe: weightlifted
# Missing from GloVe: walls.p
# Missing from GloVe: Muslim-styled
# Missing from GloVe: n'slide
# Missing from GloVe: slowly-moving
# Missing from GloVe: dirt-blonde
# Missing from GloVe: beerier
# Missing from GloVe: spider-patterned
# Missing from GloVe: rumpled-looking
# Missing from GloVe: Gray-blue
# Missing from GloVe: Tourist-Info
# Missing from GloVe: carrying-harness
# Missing from GloVe: water-dancing
# Missing from GloVe: MoonBounce
# Missing from GloVe: food-catering
# Missing from GloVe: frisbree
# Missing from GloVe: eeyeing
# Missing from GloVe: mime-like
# Missing from GloVe: sari-garbed
# Missing from GloVe: payfully
# Missing from GloVe: cruisship
# Missing from GloVe: man-drawn
# Missing from GloVe: crooswalk
# Missing from GloVe: razzling
# Missing from GloVe: boat-man
# Missing from GloVe: Gowned
# Missing from GloVe: partially-draped
# Missing from GloVe: bodysurfs
# Missing from GloVe: THEFACESHOP
# Missing from GloVe: two-monitored
# Missing from GloVe: fishnet-style
# Missing from GloVe: tanned-skin
# Missing from GloVe: long-spandex
# Missing from GloVe: oriential
# Missing from GloVe: street-cone
# Missing from GloVe: stone-brick
# Missing from GloVe: clover-filled
# Missing from GloVe: streetway
# Missing from GloVe: turquoise-wearing
# Missing from GloVe: tight-packed
# Missing from GloVe: stadning
# Missing from GloVe: passifier
# Missing from GloVe: ractrack
# Missing from GloVe: Mandarin-style
# Missing from GloVe: Billy-Goat
# Missing from GloVe: empty-saddled
# Missing from GloVe: canooers
# Missing from GloVe: tobaggan
# Missing from GloVe: dog-shirt
# Missing from GloVe: Kayacker
# Missing from GloVe: white-hooded
# Missing from GloVe: orange-lined
# Missing from GloVe: plungles
# Missing from GloVe: distracted-looking
# Missing from GloVe: green-framed
# Missing from GloVe: URKLE
# Missing from GloVe: KRUGT
# Missing from GloVe: mid-dress
# Missing from GloVe: ZCHTV
# Missing from GloVe: PRZEMEK
# Missing from GloVe: pole-handled
# Missing from GloVe: blue-checkered
# Missing from GloVe: Respol
# Missing from GloVe: blue-robed
# Missing from GloVe: L6H-320
# Missing from GloVe: fly-plane
# Missing from GloVe: Palomitas
# Missing from GloVe: Tehse
# Missing from GloVe: decrepitness
# Missing from GloVe: Gubbngen
# Missing from GloVe: brown-sand
# Missing from GloVe: early-bald
# Missing from GloVe: mid-dribble
# Missing from GloVe: mid-courth
# Missing from GloVe: butterfly-catcher
# Missing from GloVe: wetsuit-clad
# Missing from GloVe: arena-like
# Missing from GloVe: potty-potty
# Missing from GloVe: long-rodded
# Missing from GloVe: contracption
# Missing from GloVe: A.group
# Missing from GloVe: t-shrt
# Missing from GloVe: waaves
# Missing from GloVe: reggae-style
# Missing from GloVe: semi-circled
# Missing from GloVe: dandelion-strewn
# Missing from GloVe: RefWorkss
# Missing from GloVe: cOS.
# Missing from GloVe: Amish-looking
# Missing from GloVe: waing
# Missing from GloVe: foggyday
# Missing from GloVe: frog-shaped
# Missing from GloVe: tire-shaped
# Missing from GloVe: creme-colored
# Missing from GloVe: belly-smacker
# Missing from GloVe: dimlight
# Missing from GloVe: sun-glassed
# Missing from GloVe: semi-collapsed
# Missing from GloVe: gauzey
# Missing from GloVe: portrate
# Missing from GloVe: tablecloth-covered
# Missing from GloVe: competeition
# Missing from GloVe: foreround
# Missing from GloVe: close-together
# Missing from GloVe: jean-shorts
# Missing from GloVe: treefilled
# Missing from GloVe: mid-dance
# Missing from GloVe: israei
# Missing from GloVe: clay-worker
# Missing from GloVe: rock-clibbing
# Missing from GloVe: ball-bearer
# Missing from GloVe: dress-type
# Missing from GloVe: pre-school-aged
# Missing from GloVe: sub-pavement
# Missing from GloVe: turquoise-and-olive-green
# Missing from GloVe: fitls
# Missing from GloVe: road.An
# Missing from GloVe: Chinese-printed
# Missing from GloVe: Museumsbutikken
# Missing from GloVe: plling
# Missing from GloVe: food-catching
# Missing from GloVe: sportwoman
# Missing from GloVe: historic-looking
# Missing from GloVe: Brown-skinned
# Missing from GloVe: wooden-paneled
# Missing from GloVe: day-hiker
# Missing from GloVe: also-sleeping
# Missing from GloVe: yellow-fringed
# Missing from GloVe: mural-covered
# Missing from GloVe: Sorvette
# Missing from GloVe: shawled
# Missing from GloVe: shrowded
# Missing from GloVe: hand-railing
# Missing from GloVe: cathcer
# Missing from GloVe: hand-molds
# Missing from GloVe: bird-looking
# Missing from GloVe: Gondolieri
# Missing from GloVe: dacshund
# Missing from GloVe: O-Backs
# Missing from GloVe: T-shift
# Missing from GloVe: Recked
# Missing from GloVe: men4
# Missing from GloVe: dirtbed
# Missing from GloVe: push-toy
# Missing from GloVe: borader
# Missing from GloVe: Pescaderia
# Missing from GloVe: Carnhart
# Missing from GloVe: Abarrotes
# Missing from GloVe: kerchief-wearing
# Missing from GloVe: army-colored
# Missing from GloVe: Twome
# Missing from GloVe: EASTA
# Missing from GloVe: Laperla
# Missing from GloVe: scantily-costumed
# Missing from GloVe: skin-the-cat
# Missing from GloVe: Craftslady
# Missing from GloVe: snowploe
# Missing from GloVe: ornately-decorated
# Missing from GloVe: orangesunset
# Missing from GloVe: downsteps
# Missing from GloVe: pier-like
# Missing from GloVe: woooden
# Missing from GloVe: OBLIGATOIRE
# Missing from GloVe: Ypoung
# Missing from GloVe: Flyre
# Missing from GloVe: window-holes
# Missing from GloVe: streetpole
# Missing from GloVe: intricately-patterned
# Missing from GloVe: fingerhold
# Missing from GloVe: Tajdaw
# Missing from GloVe: ARRIVO
# Missing from GloVe: jumpos
# Missing from GloVe: wood-chipping
# Missing from GloVe: bare-midriffed
# Missing from GloVe: head-dressed
# Missing from GloVe: trashed-filled
# Missing from GloVe: pub-laden
# Missing from GloVe: Bisuter
# Missing from GloVe: Bykuwski
# Missing from GloVe: Fossar
# Missing from GloVe: Moreres
# Missing from GloVe: CRAZI
# Missing from GloVe: GlamWiki
# Missing from GloVe: swing-type
# Missing from GloVe: dirtracing
# Missing from GloVe: moutainside
# Missing from GloVe: play-swordfighting
# Missing from GloVe: craftzine.com
# Missing from GloVe: outfut
# Missing from GloVe: under-wear
# Missing from GloVe: snowpile
# Missing from GloVe: sport-team
# Missing from GloVe: gray-suited
# Missing from GloVe: water-spraying
# Missing from GloVe: baby-carrier
# Missing from GloVe: fiveteen
# Missing from GloVe: Sillhouttes
# Missing from GloVe: wide-bimmed
# Missing from GloVe: striped-tunic
# Missing from GloVe: G?uys
# Missing from GloVe: one-piece-suits
# Missing from GloVe: sled-like
# Missing from GloVe: parakiting
# Missing from GloVe: Skimply
# Missing from GloVe: backstand
# Missing from GloVe: popcycles
# Missing from GloVe: Riwal
# Missing from GloVe: perfors
# Missing from GloVe: furocious
# Missing from GloVe: blays
# Missing from GloVe: GONTAGA
# Missing from GloVe: concrete.An
# Missing from GloVe: facepaintings
# Missing from GloVe: Landscope
# Missing from GloVe: red-dressed
# Missing from GloVe: Para-Olympians
# Missing from GloVe: spectates
# Missing from GloVe: parasurfs
# Missing from GloVe: sweater-clad
# Missing from GloVe: Scantily-clad
# Missing from GloVe: life-vests
# Missing from GloVe: vaulated
# Missing from GloVe: home-styled
# Missing from GloVe: blue-draped
# Missing from GloVe: dark-headed
# Missing from GloVe: aggitates
# Missing from GloVe: almost-pristine
# Missing from GloVe: Octopus-like
# Missing from GloVe: nose-deep
# Missing from GloVe: green-wheeled
# Missing from GloVe: party.Two
# Missing from GloVe: rainling
# Missing from GloVe: yellow-walled
# Missing from GloVe: shaven-head
# Missing from GloVe: Ravins
# Missing from GloVe: fadora
# Missing from GloVe: GELATERIA
# Missing from GloVe: dreeds
# Missing from GloVe: Dirtbikers
# Missing from GloVe: Vally-ball
# Missing from GloVe: sea-saws
# Missing from GloVe: shoo-shes
# Missing from GloVe: shh-ing
# Missing from GloVe: lego-built
# Missing from GloVe: gloved-hand
# Missing from GloVe: dirt-laden
# Missing from GloVe: Utiah
# Missing from GloVe: pink-lensed
# Missing from GloVe: half-assembled
# Missing from GloVe: color-drained
# Missing from GloVe: chair-swing
# Missing from GloVe: radio-making
# Missing from GloVe: oppsing
# Missing from GloVe: basett
# Missing from GloVe: red-gray
# Missing from GloVe: grimmaces
# Missing from GloVe: eyese
# Missing from GloVe: hsirt
# Missing from GloVe: wall-ride
# Missing from GloVe: brick-and-glass
# Missing from GloVe: glove-covered
# Missing from GloVe: cup-o-noodles
# Missing from GloVe: over-the-street
# Missing from GloVe: Pleople
# Missing from GloVe: mid-drifts
# Missing from GloVe: Gothic-dressed
# Missing from GloVe: Obamacondoms.com
# Missing from GloVe: aluminum-colored
# Missing from GloVe: KEBAP
# Missing from GloVe: slalom-like
# Missing from GloVe: Parachuter
# Missing from GloVe: brightly-clothed
# Missing from GloVe: underhang
# Missing from GloVe: happy-appearing
# Missing from GloVe: PlNe
# Missing from GloVe: cranberry-colored
# Missing from GloVe: riverrafting
# Missing from GloVe: hooded-coat
# Missing from GloVe: fire-dancers
# Missing from GloVe: fronmt
# Missing from GloVe: build-n-paint
# Missing from GloVe: Bienvenus
# Missing from GloVe: tiretracks
# Missing from GloVe: green-covered
# Missing from GloVe: green-patterned
# Missing from GloVe: VHJ-969
# Missing from GloVe: checker-table
# Missing from GloVe: bagpipe.co.uk
# Missing from GloVe: TRiomphe
# Missing from GloVe: shop-filled
# Missing from GloVe: back-round
# Missing from GloVe: show-shoers
# Missing from GloVe: decortive
# Missing from GloVe: kickboxing-style
# Missing from GloVe: glowing-hot
# Missing from GloVe: crotch-level
# Missing from GloVe: rellow
# Missing from GloVe: Carpintaria
# Missing from GloVe: Airgame
# Missing from GloVe: suited-man
# Missing from GloVe: blond-dyed
# Missing from GloVe: wrestilng
# Missing from GloVe: multi-piercings
# Missing from GloVe: mid-speach
# Missing from GloVe: tube-dress
# Missing from GloVe: name-badge
# Missing from GloVe: teeter-taughter
# Missing from GloVe: graffiti-decorated
# Missing from GloVe: mid-climb
# Missing from GloVe: Japanese-sponsored
# Missing from GloVe: beanches
# Missing from GloVe: decoy-animal
# Missing from GloVe: betbook
# Missing from GloVe: Santa-hats
# Missing from GloVe: British-looking
# Missing from GloVe: red-bodied
# Missing from GloVe: grss
# Missing from GloVe: fton
# Missing from GloVe: Arm-strokes
# Missing from GloVe: halmets
# Missing from GloVe: Conococo
# Missing from GloVe: throughwindow
# Missing from GloVe: net-less
# Missing from GloVe: mocha-brown
# Missing from GloVe: flavor-syrup
# Missing from GloVe: Pink-haired
# Missing from GloVe: clear-colored
# Missing from GloVe: short-and-shirt
# Missing from GloVe: carreis
# Missing from GloVe: tongee
# Missing from GloVe: chalk-artist
# Missing from GloVe: doo-rags
# Missing from GloVe: Caviler
# Missing from GloVe: flower-festooned
# Missing from GloVe: wind-toys
# Missing from GloVe: back-bend
# Missing from GloVe: Colorfully-dressed
# Missing from GloVe: polbru
# Missing from GloVe: windboard
# Missing from GloVe: Weirmeiner
# Missing from GloVe: pink-draped
# Missing from GloVe: clownlike
# Missing from GloVe: midpitch
# Missing from GloVe: bar-covered
# Missing from GloVe: kewpie-doll
# Missing from GloVe: colapsable
# Missing from GloVe: one-fourths
# Missing from GloVe: Yukla
# Missing from GloVe: bust-style
# Missing from GloVe: wire-walled
# Missing from GloVe: medatative
# Missing from GloVe: cue-stick
# Missing from GloVe: mock-conducting
# Missing from GloVe: husky-like
# Missing from GloVe: wearhing
# Missing from GloVe: graffiti-ed
# Missing from GloVe: dark-orange
# Missing from GloVe: hurdle-jumper
# Missing from GloVe: wmoan
# Missing from GloVe: stunt-bicyclist
# Missing from GloVe: cacthing
# Missing from GloVe: minerature
# Missing from GloVe: Corn-hole
# Missing from GloVe: frisbeen
# Missing from GloVe: Egytian-like
# Missing from GloVe: graffiti-heavy
# Missing from GloVe: Youngle
# Missing from GloVe: white-jerseyed
# Missing from GloVe: wearfing
# Missing from GloVe: camera-left
# Missing from GloVe: read-haired
# Missing from GloVe: Bat-woman
# Missing from GloVe: caution-tape
# Missing from GloVe: ramor
# Missing from GloVe: insecticide-free
# Missing from GloVe: Potao
# Missing from GloVe: three-stories
# Missing from GloVe: Cuido
# Missing from GloVe: Cyranka
# Missing from GloVe: ConstructionBike
# Missing from GloVe: yellow-glowing
# Missing from GloVe: sharp-lined
# Missing from GloVe: Kingsworth
# Missing from GloVe: cap-clad
# Missing from GloVe: BismarckstraBe
# Missing from GloVe: sand-trap
# Missing from GloVe: currycombs
# Missing from GloVe: gran-daughter
# Missing from GloVe: stick-pole
# Missing from GloVe: shutter-doors
# Missing from GloVe: stamds
# Missing from GloVe: red-lidded
# Missing from GloVe: bungee-type
# Missing from GloVe: Burnese
# Missing from GloVe: keffiyahs
# Missing from GloVe: yarn-like
# Missing from GloVe: Roller-blades
# Missing from GloVe: 40ts
# Missing from GloVe: conoe
# Missing from GloVe: coffee-burst
# Missing from GloVe: work-type
# Missing from GloVe: Neude
# Missing from GloVe: SelektMail
# Missing from GloVe: narby
# Missing from GloVe: scared-looking
# Missing from GloVe: swimcap
# Missing from GloVe: torso-deep
# Missing from GloVe: colorfully-dressed
# Missing from GloVe: cappedhills
# Missing from GloVe: freeword
# Missing from GloVe: item-filled
# Missing from GloVe: cow-patterned
# Missing from GloVe: Barechested
# Missing from GloVe: rollskating
# Missing from GloVe: bull-dogging
# Missing from GloVe: RollerSkaters
# Missing from GloVe: free-climb
# Missing from GloVe: microscope-like
# Missing from GloVe: highlighter-hued
# Missing from GloVe: holding-up
# Missing from GloVe: high-legged
# Missing from GloVe: paw-spotted
# Missing from GloVe: popscicles
# Missing from GloVe: long-jumper
# Missing from GloVe: Mariache
# Missing from GloVe: phone-car
# Missing from GloVe: Nastavowich
# Missing from GloVe: Beatermix
# Missing from GloVe: pink-bottomed
# Missing from GloVe: partly-cloudy
# Missing from GloVe: small-brimmed
# Missing from GloVe: nice-weather
# Missing from GloVe: rocky-lined
# Missing from GloVe: brick-floored
# Missing from GloVe: prestends
# Missing from GloVe: Unhappy-looking
# Missing from GloVe: muxzzled
# Missing from GloVe: para-glides
# Missing from GloVe: scubba
# Missing from GloVe: bicycle-cross
# Missing from GloVe: toy-chewing
# Missing from GloVe: brown-spotted
# Missing from GloVe: partially-furled
# Missing from GloVe: indescript
# Missing from GloVe: motor-equipped
# Missing from GloVe: half-top
# Missing from GloVe: Mountain-Dew
# Missing from GloVe: lavender-patterned
# Missing from GloVe: talk-top
# Missing from GloVe: shorts-clad
# Missing from GloVe: tin-wrapped
# Missing from GloVe: photograhi
# Missing from GloVe: ear-gear
# Missing from GloVe: balance-beam
# Missing from GloVe: Seahawkss
# Missing from GloVe: multi-arched
# Missing from GloVe: african-Americans
# Missing from GloVe: brindle-colored
# Missing from GloVe: guiutarist
# Missing from GloVe: hoop-like
# Missing from GloVe: convention-type
# Missing from GloVe: corn-looking
# Missing from GloVe: Oktoberfest-themed
# Missing from GloVe: lake-beach
# Missing from GloVe: outise
# Missing from GloVe: Farmosa
# Missing from GloVe: swing-toy
# Missing from GloVe: brightly-colred
# Missing from GloVe: Bus.co.uk
# Missing from GloVe: scar-crow
# Missing from GloVe: Twho
# Missing from GloVe: graffiti-marked
# Missing from GloVe: cage-style
# Missing from GloVe: raling
# Missing from GloVe: Fadaw
# Missing from GloVe: Victorian-type
# Missing from GloVe: red-seated
# Missing from GloVe: trail-full
# Missing from GloVe: posign
# Missing from GloVe: Absoluteily
# Missing from GloVe: dorm-room-like
# Missing from GloVe: corn-rows
# Missing from GloVe: dance-wear
# Missing from GloVe: news-casting
# Missing from GloVe: west-style
# Missing from GloVe: fence-like
# Missing from GloVe: jumpropes
# Missing from GloVe: rustric
# Missing from GloVe: erotically-dressed
# Missing from GloVe: para-surfing
# Missing from GloVe: non-grassy
# Missing from GloVe: mud-wrestle
# Missing from GloVe: wading-pool
# Missing from GloVe: mudfight
# Missing from GloVe: crowd-filled
# Missing from GloVe: Maralis
# Missing from GloVe: Cofain
# Missing from GloVe: brindle-coated
# Missing from GloVe: NARVESEN
# Missing from GloVe: RollerBlading
# Missing from GloVe: phrase'Scrambler
# Missing from GloVe: malabarism
# Missing from GloVe: off-frame
# Missing from GloVe: Mutltiple
# Missing from GloVe: kilt-like
# Missing from GloVe: Cattle-drawn
# Missing from GloVe: atyl-atyl
# Missing from GloVe: sports-bra
# Missing from GloVe: dooorway
# Missing from GloVe: am-track
# Missing from GloVe: brown-and-black
# Missing from GloVe: conoes
# Missing from GloVe: frightened-looking
# Missing from GloVe: Kawasaki-branded
# Missing from GloVe: yellow-check
# Missing from GloVe: tan-and-white
# Missing from GloVe: gold-fringed
# Missing from GloVe: fire-fightes
# Missing from GloVe: extravagantly-haired
# Missing from GloVe: stiffly-posed
# Missing from GloVe: power-drill
# Missing from GloVe: curly-haird
# Missing from GloVe: bra-tops
# Missing from GloVe: bicyler
# Missing from GloVe: race-cars
# Missing from GloVe: GDSD
# Missing from GloVe: bunchh
# Missing from GloVe: food.a
# Missing from GloVe: black-plaid
# Missing from GloVe: rockside
# Missing from GloVe: street-shot
# Missing from GloVe: ambra.com
# Missing from GloVe: colorfully-decorated
# Missing from GloVe: dress-ed
# Missing from GloVe: perforced
# Missing from GloVe: probuilt
# Missing from GloVe: meetinghall
# Missing from GloVe: pink-hooded
# Missing from GloVe: gallopsing
# Missing from GloVe: Cariboos
# Missing from GloVe: back-view
# Missing from GloVe: orange-hooded
# Missing from GloVe: seedoo
# Missing from GloVe: bikeathon
# Missing from GloVe: horizontally-suspended
# Missing from GloVe: jumpinjg
# Missing from GloVe: thick-striped
# Missing from GloVe: accends
# Missing from GloVe: endorsement-covered
# Missing from GloVe: red-clothed
# Missing from GloVe: curly-blond-haired
# Missing from GloVe: monkey-bars
# Missing from GloVe: waffle-style
# Missing from GloVe: telephot
# Missing from GloVe: jumphouse
# Missing from GloVe: Tye-dye
# Missing from GloVe: weairng
# Missing from GloVe: green-glow
# Missing from GloVe: wind-surfer
# Missing from GloVe: MotorCycles
# Missing from GloVe: post-throw
# Missing from GloVe: sweashirt
# Missing from GloVe: Unexisting
# Missing from GloVe: pettipants
# Missing from GloVe: fronr
# Missing from GloVe: bigwheels
# Missing from GloVe: green-suited
# Missing from GloVe: winter-gear
# Missing from GloVe: divind
# Missing from GloVe: roller-hockey
# Missing from GloVe: Roller-Hockey
# Missing from GloVe: steel-works
# Missing from GloVe: Head-dressed
# Missing from GloVe: LMMVSD
# Missing from GloVe: partially-painted
# Missing from GloVe: restaurant-like
# Missing from GloVe: jack-o-laterns
# Missing from GloVe: trailer-load
# Missing from GloVe: trendily-dressed
# Missing from GloVe: dobbermen
# Missing from GloVe: Bicycler
# Missing from GloVe: shadow-dappled
# Missing from GloVe: twine-wrapped
# Missing from GloVe: spray-paints
# Missing from GloVe: hogtying
# Missing from GloVe: Moseride
# Missing from GloVe: Rees.com
# Missing from GloVe: loom-type
# Missing from GloVe: plaza-like
# Missing from GloVe: victorian-styled
# Missing from GloVe: Afghan-hound
# Missing from GloVe: Harley-Davison
# Missing from GloVe: dingy-looking
# Missing from GloVe: German-shepherd
# Missing from GloVe: FREEWORD
# Missing from GloVe: not-so-candidly
# Missing from GloVe: multi-columned
# Missing from GloVe: distnat
# Missing from GloVe: toddler-age
# Missing from GloVe: serious-faced
# Missing from GloVe: big-teethed
# Missing from GloVe: breathe-in
# Missing from GloVe: re-shingles
# Missing from GloVe: marine-life-themed
# Missing from GloVe: waeribng
# Missing from GloVe: catcher-with
# Missing from GloVe: skislope
# Missing from GloVe: shirt-sleeved
# Missing from GloVe: un-pictured
# Missing from GloVe: heavily-marked
# Missing from GloVe: equpitment
# Missing from GloVe: inline-skates
# Missing from GloVe: moutnain
# Missing from GloVe: fishscales
# Missing from GloVe: Hobophobia
# Missing from GloVe: derbis
# Missing from GloVe: work-shirt
# Missing from GloVe: half-diving
# Missing from GloVe: orange-stained
# Missing from GloVe: fribee
# Missing from GloVe: RR-16
# Missing from GloVe: promenade-like
# Missing from GloVe: Triuneo
# Missing from GloVe: yellow-floral
# Missing from GloVe: nail-gloss
# Missing from GloVe: watersking
# Missing from GloVe: skotch
# Missing from GloVe: marathan
# Missing from GloVe: grayhounds
# Missing from GloVe: oerson
# Missing from GloVe: skatesboards
# Missing from GloVe: spraypaints
# Missing from GloVe: mucisians
# Missing from GloVe: mucisian
# Missing from GloVe: owman
# Missing from GloVe: iceskater
# Missing from GloVe: lifegaurds
# Missing from GloVe: sleepign
# Missing from GloVe: swinning
# Missing from GloVe: athleates
# Missing from GloVe: weearing
# Missing from GloVe: sleepng
# Missing from GloVe: walkind
# Missing from GloVe: guesturing
# Missing from GloVe: skydyving
# Missing from GloVe: motocyclist
# Missing from GloVe: Indivisuals
# Missing from GloVe: twerks
# Missing from GloVe: finderspot
# Missing from GloVe: Anti-police
# Missing from GloVe: wearinga
# Missing from GloVe: soccerr
# Missing from GloVe: tattoe
# Missing from GloVe: folk-guitar
# Missing from GloVe: streen
# Missing from GloVe: trapeeze
# Missing from GloVe: outdoros
# Missing from GloVe: delivery-boy
# Missing from GloVe: foodstand
# Missing from GloVe: instruements
# Missing from GloVe: treaks
# Missing from GloVe: paddeling
# Missing from GloVe: checker-patterned
# Missing from GloVe: youga
# Missing from GloVe: hands/paws
# Missing from GloVe: Estacione
# Missing from GloVe: homeless-looking
# Missing from GloVe: tomato-like
# Missing from GloVe: reparied
# Missing from GloVe: Motorcylist
# Missing from GloVe: pwople
# Missing from GloVe: parasailed
# Missing from GloVe: scuplting
# Missing from GloVe: suglasses
# Missing from GloVe: hulahooping
# Missing from GloVe: competeive
# Missing from GloVe: praciticing
# Missing from GloVe: volelyball
# Missing from GloVe: auditoriam
# Missing from GloVe: winab
# Missing from GloVe: twom
# Missing from GloVe: walkds
# Missing from GloVe: pipe-fitters
# Missing from GloVe: trumbone
# Missing from GloVe: graffitit
# Missing from GloVe: compount
# Missing from GloVe: frisbess
# Missing from GloVe: truncks
# Missing from GloVe: outddors
# Missing from GloVe: lickes
# Missing from GloVe: pellam
# Missing from GloVe: lepuka
# Missing from GloVe: pothuna
# Missing from GloVe: badacow
# Missing from GloVe: hand-spinning
# Missing from GloVe: trackl
# Missing from GloVe: slindg
# Missing from GloVe: outside3
# Missing from GloVe: repairng
# Missing from GloVe: chellos
# Missing from GloVe: grillout
# Missing from GloVe: wiemaraner
# Missing from GloVe: motocrycles
# Missing from GloVe: preperes
# Missing from GloVe: microsope
# Missing from GloVe: hoolahoop
# Missing from GloVe: outsidee
# Missing from GloVe: windowasher
# Missing from GloVe: chainshaw
# Missing from GloVe: bridesmades
# Missing from GloVe: cowded
# Missing from GloVe: goali
# Missing from GloVe: seranading
# Missing from GloVe: shi-tzu
# Missing from GloVe: Sk8tr
# Missing from GloVe: mid-trick
# Missing from GloVe: sleepiing
# Missing from GloVe: outsided
# Missing from GloVe: lacrose
# Missing from GloVe: womanis
# Missing from GloVe: younster
# Missing from GloVe: musicina
# Missing from GloVe: runds
# Missing from GloVe: playinh
# Missing from GloVe: standign
# Missing from GloVe: seaated
# Missing from GloVe: aslep
# Missing from GloVe: motcross
# Missing from GloVe: otudoors
# Missing from GloVe: blue-hair
# Missing from GloVe: Cleanshaven
# Missing from GloVe: comboy
# Missing from GloVe: gymnest
# Missing from GloVe: thunderstorming
# Missing from GloVe: tap-dances
# Missing from GloVe: althlete
# Missing from GloVe: slidng
# Missing from GloVe: sludgehammer
# Missing from GloVe: unicycler
# Missing from GloVe: landromat
# Missing from GloVe: poorly-dressed
# Missing from GloVe: towad
# Missing from GloVe: kayacker
# Missing from GloVe: reenacters
# Missing from GloVe: miscroscope
# Missing from GloVe: asleeping
# Missing from GloVe: azure-clad
# Missing from GloVe: motorycycle
# Missing from GloVe: teenieboppers
# Missing from GloVe: tattoeed
# Missing from GloVe: whicle
# Missing from GloVe: stanfing
# Missing from GloVe: dessed
# Missing from GloVe: roadworker
# Missing from GloVe: coraling
# Missing from GloVe: eatign
# Missing from GloVe: waterboarder
# Missing from GloVe: skiman
# Missing from GloVe: swingswet
# Missing from GloVe: byciclist
# Missing from GloVe: oaintball
# Missing from GloVe: walkpath
# Missing from GloVe: competitevly
# Missing from GloVe: buill
# Missing from GloVe: donkey-pulled
# Missing from GloVe: lacrosee
# Missing from GloVe: aleep
# Missing from GloVe: racelers
# Missing from GloVe: quarel
# Missing from GloVe: gatehring
# Missing from GloVe: repaing
# Missing from GloVe: tramopline
# Missing from GloVe: snowfort
# Missing from GloVe: passerbyers
# Missing from GloVe: bathrub
# Missing from GloVe: waterskiier
# Missing from GloVe: corwd
# Missing from GloVe: womna
# Missing from GloVe: preaping
# Missing from GloVe: basesball
# Missing from GloVe: Washington-esque
# Missing from GloVe: hyposaurarius
# Missing from GloVe: boccee
# Missing from GloVe: musicials
# Missing from GloVe: gestering
# Missing from GloVe: grapneling
# Missing from GloVe: dishelved
# Missing from GloVe: cylist
# Missing from GloVe: angrly
# Missing from GloVe: showshoes
# Missing from GloVe: midkick
# Missing from GloVe: popsycles
# Missing from GloVe: ferris-wheel
# Missing from GloVe: skaeboard
# Missing from GloVe: border-guard
# Missing from GloVe: basbeball
# Missing from GloVe: perofrming
# Missing from GloVe: hokding
# Missing from GloVe: stnads
# Missing from GloVe: basedball
# Missing from GloVe: campire
# Missing from GloVe: weariing
# Missing from GloVe: soccerfield
# Missing from GloVe: blances
# Missing from GloVe: airplace
# Missing from GloVe: circuis
# Missing from GloVe: pro-skateboarder
# Missing from GloVe: rockclimber
# Missing from GloVe: chassing
# Missing from GloVe: oceam
# Missing from GloVe: hackysac
# Missing from GloVe: ridse
# Missing from GloVe: ladiesare
# Missing from GloVe: kayake
# Missing from GloVe: outdside
# Missing from GloVe: performning
# Missing from GloVe: Sky-watcher
# Missing from GloVe: unusually-dressed
# Missing from GloVe: potesting
# Missing from GloVe: accumilation
# Missing from GloVe: hotscotch
# Missing from GloVe: athete
# Missing from GloVe: mowes
# Missing from GloVe: skyskraper
# Missing from GloVe: shirst
# Missing from GloVe: derbying
# Missing from GloVe: empty-mouthed
# Missing from GloVe: asleeo
# Missing from GloVe: stanging
# Missing from GloVe: drinkign
# Missing from GloVe: graffatii
# Missing from GloVe: erthquake
# Missing from GloVe: martahon
# Missing from GloVe: proforming
# Missing from GloVe: blonde-headed
# Missing from GloVe: walk-do
# Missing from GloVe: snowsuite
# Missing from GloVe: chihuhua
# Missing from GloVe: pole-vaults
# Missing from GloVe: sportsing
# Missing from GloVe: budweisar
# Missing from GloVe: prepairs
# Missing from GloVe: takse
# Missing from GloVe: wearking
# Missing from GloVe: Somene
# Missing from GloVe: purple-shirted
# Missing from GloVe: bicylclists
# Missing from GloVe: outoors
# Missing from GloVe: vaperising
# Missing from GloVe: outdoot
# Missing from GloVe: bumblebee-colored
# Missing from GloVe: tobbogans
# Missing from GloVe: childerent
# Missing from GloVe: sandal-clad
# Missing from GloVe: fertilizering
# Missing from GloVe: watchingt
# Missing from GloVe: scultupres
# Missing from GloVe: Grafffiti
# Missing from GloVe: homcoming
# Missing from GloVe: stanindg
# Missing from GloVe: ingnue
# Missing from GloVe: sheherd
# Missing from GloVe: veterenarian
# Missing from GloVe: indorrs
# Missing from GloVe: foundtain
# Missing from GloVe: performnef
# Missing from GloVe: doord
# Missing from GloVe: America-themed
# Missing from GloVe: out-walk
# Missing from GloVe: whithhis
# Missing from GloVe: muscicians
# Missing from GloVe: weaaring
# Missing from GloVe: weras
# Missing from GloVe: wairs
# Missing from GloVe: spa/nails/hair
# Missing from GloVe: scark
# Missing from GloVe: Stickthrower
# Missing from GloVe: hrose
# Missing from GloVe: ocaen
# Missing from GloVe: greyhouds
# Missing from GloVe: twilring
# Missing from GloVe: checker.s
# Missing from GloVe: aduts
# Missing from GloVe: pankcake
# Missing from GloVe: Severl
# Missing from GloVe: partarke
# Missing from GloVe: yelliing
# Missing from GloVe: ring-around-the-rosies
# Missing from GloVe: bincoculars
# Missing from GloVe: couhc
# Missing from GloVe: streetgame
# Missing from GloVe: romaticly
# Missing from GloVe: happeningo
# Missing from GloVe: brown-hooded
# Missing from GloVe: eneds
# Missing from GloVe: motorcylists
# Missing from GloVe: playinhg
# Missing from GloVe: handband
# Missing from GloVe: pillos
# Missing from GloVe: isplaying
# Missing from GloVe: swimmign
# Missing from GloVe: richshaw
# Missing from GloVe: all-gender
# Missing from GloVe: inred
# Missing from GloVe: weinging
# Missing from GloVe: facility/area
# Missing from GloVe: sowrdsman
# Missing from GloVe: handrials
# Missing from GloVe: apcolypse
# Missing from GloVe: comtemplates
# Missing from GloVe: rcowd
# Missing from GloVe: exchaning
# Missing from GloVe: cop.s
# Missing from GloVe: wriring
# Missing from GloVe: occasssion
# Missing from GloVe: contsruction
# Missing from GloVe: wall-menus
# Missing from GloVe: stree5t
# Missing from GloVe: kssing
# Missing from GloVe: TICKILING
# Missing from GloVe: hydraphobic
# Missing from GloVe: grrom
# Missing from GloVe: bannner
# Missing from GloVe: classroomm
# Missing from GloVe: sleepingc
# Missing from GloVe: M.C.s
# Missing from GloVe: poterry
# Missing from GloVe: in-complete
# Missing from GloVe: moody-looking
# Missing from GloVe: spelunks
# Missing from GloVe: dctors
# Missing from GloVe: candlee
# Missing from GloVe: comi-con
# Missing from GloVe: dreesed
# Missing from GloVe: tWO
# Missing from GloVe: anoterh
# Missing from GloVe: videohraphers
# Missing from GloVe: snine
# Missing from GloVe: wearinh
# Missing from GloVe: forumating
# Missing from GloVe: brownb
# Missing from GloVe: Checmical
# Missing from GloVe: telescoper
# Missing from GloVe: standinig
# Missing from GloVe: relationaship
# Missing from GloVe: litered
# Missing from GloVe: rainbow-dyed
# Missing from GloVe: morotcycle
# Missing from GloVe: at-capacity
# Missing from GloVe: idditarod
# Missing from GloVe: windsufring
# Missing from GloVe: jouls
# Missing from GloVe: olymipic
# Missing from GloVe: Thewomen
# Missing from GloVe: peocock
# Missing from GloVe: demonstator
# Missing from GloVe: luggle
# Missing from GloVe: ollivanders
# Missing from GloVe: passerby-er
# Missing from GloVe: skting
# Missing from GloVe: fake-beard
# Missing from GloVe: listeining
# Missing from GloVe: Stronginthearm
# Missing from GloVe: sculting
# Missing from GloVe: umbralla
# Missing from GloVe: ricb
# Missing from GloVe: underrclithes
# Missing from GloVe: pflying
# Missing from GloVe: microsopic
# Missing from GloVe: wwalking
# Missing from GloVe: besdie
# Missing from GloVe: shoeGasm
# Missing from GloVe: lpayers
# Missing from GloVe: proto-hipster
# Missing from GloVe: parashutes
# Missing from GloVe: foothpath
# Missing from GloVe: pattleboating
# Missing from GloVe: sttands
# Missing from GloVe: acnhored
# Missing from GloVe: trambled
# Missing from GloVe: interpertive
# Missing from GloVe: flirtng
# Missing from GloVe: wiedling
# Missing from GloVe: guggling
# Missing from GloVe: figherfighers
# Missing from GloVe: vigirously
# Missing from GloVe: mountina
# Missing from GloVe: ocnea
# Missing from GloVe: desolete
# Missing from GloVe: consisitng
# Missing from GloVe: beachgoing
# Missing from GloVe: maktes
# Missing from GloVe: stabds
# Missing from GloVe: abowl
# Missing from GloVe: motorbik
# Missing from GloVe: greenry
# Missing from GloVe: jocket
# Missing from GloVe: tpicture
# Missing from GloVe: pointign
# Missing from GloVe: expirament
# Missing from GloVe: pursuiting
# Missing from GloVe: renasance
# Missing from GloVe: oldly
# Missing from GloVe: polka-based
# Missing from GloVe: yardsaling
# Missing from GloVe: stree.t
# Missing from GloVe: taekondo
# Missing from GloVe: princecess
# Missing from GloVe: Elctronics
# Missing from GloVe: cjild
# Missing from GloVe: pavenment
# Missing from GloVe: sidewalke
# Missing from GloVe: claranet
# Missing from GloVe: grouns
# Missing from GloVe: ggrass
# Missing from GloVe: huppe
# Missing from GloVe: adult.s
# Missing from GloVe: ebach
# Missing from GloVe: swaeting
# Missing from GloVe: tounrament
# Missing from GloVe: rifing
# Missing from GloVe: shoeshining
# Missing from GloVe: shoeshiners
# Missing from GloVe: drivies
# Missing from GloVe: landmill
# Missing from GloVe: pnacho
# Missing from GloVe: playingbag
# Missing from GloVe: OOOHS
# Missing from GloVe: AAAHS
# Missing from GloVe: clothees
# Missing from GloVe: clairnet
# Missing from GloVe: j-walking
# Missing from GloVe: speinding
# Missing from GloVe: chirldern
# Missing from GloVe: feck-going
# Missing from GloVe: protectnig
# Missing from GloVe: deleivering
# Missing from GloVe: cocach
# Missing from GloVe: caot
# Missing from GloVe: peroccupied
# Missing from GloVe: photograhper
# Missing from GloVe: recently-cut
# Missing from GloVe: carrriages
# Missing from GloVe: Fully-padded
# Missing from GloVe: ptient
# Missing from GloVe: celebratinng
# Missing from GloVe: kickflipping
# Missing from GloVe: altheltes
# Missing from GloVe: vvehicle
# Missing from GloVe: splots
# Missing from GloVe: weigh-scale
# Missing from GloVe: ewater
# Missing from GloVe: proffesoinal
# Missing from GloVe: Macarana
# Missing from GloVe: peoplpe
# Missing from GloVe: bucycle
# Missing from GloVe: bungeeing
# Missing from GloVe: cnducting
# Missing from GloVe: mask-wearing-man
# Missing from GloVe: rusy
# Missing from GloVe: perairs
# Missing from GloVe: colthed
# Missing from GloVe: repaied
# Missing from GloVe: labworker
# Missing from GloVe: cathers
# Missing from GloVe: beloging
# Missing from GloVe: colidascope
# Missing from GloVe: prdestian
# Missing from GloVe: pigieons
# Missing from GloVe: stnding
# Missing from GloVe: oreiental
# Missing from GloVe: passersbys
# Missing from GloVe: medium-cropped
# ...
# Missing from GloVe: unforms
# Missing from GloVe: Phinatic
# Missing from GloVe: sktaeboard
# Missing from GloVe: cheeze-its
# Missing from GloVe: city-trip
# Missing from GloVe: deepseafishing
# Missing from GloVe: tottlder
# Missing from GloVe: becasu
# Missing from GloVe: baesball
# Missing from GloVe: conservatively-dressed
# Missing from GloVe: rallly
# Missing from GloVe: celbrates
# Missing from GloVe: swigning
# Missing from GloVe: carhood
# Missing from GloVe: whipout
# Missing from GloVe: carstopped
# Missing from GloVe: ingloo
# Missing from GloVe: accoridan
# Missing from GloVe: accorian
# Missing from GloVe: mery-go-round
# Missing from GloVe: skimask
# Missing from GloVe: resucers
# Missing from GloVe: womani
# Missing from GloVe: Bare-headed
# Missing from GloVe: manwith
# Missing from GloVe: relaxees
# Missing from GloVe: jnot
# Missing from GloVe: undergarmets
# Missing from GloVe: fetish-having
# Missing from GloVe: scalpal
# Missing from GloVe: townfolks
# Missing from GloVe: indoos
# Missing from GloVe: chellist
# Missing from GloVe: backetball
# Missing from GloVe: voluneteers
# Missing from GloVe: high-spirits
# Missing from GloVe: atletes
# Missing from GloVe: wimbelton
# Missing from GloVe: prospecter
# Missing from GloVe: atands
# Missing from GloVe: patateos
# Missing from GloVe: vacatrion
# Missing from GloVe: triman
# Missing from GloVe: wriestling
# Missing from GloVe: lugggage
# Missing from GloVe: griup
# Missing from GloVe: puchas
# Missing from GloVe: gymast
# Missing from GloVe: resurant
# Missing from GloVe: tapdanced
# Missing from GloVe: gridsmaids
# Missing from GloVe: bawnfire
# Missing from GloVe: schouts
# Missing from GloVe: motorcylcle
# Missing from GloVe: plaiying
# Missing from GloVe: gray-hair
# Missing from GloVe: Girlscouts
# Missing from GloVe: moues
# Missing from GloVe: waterfrom
# Missing from GloVe: vibrand
# Missing from GloVe: pompdour
# Missing from GloVe: coung
# Missing from GloVe: Beople
# Missing from GloVe: parsurfing
# Missing from GloVe: flamesticks
# Missing from GloVe: apocolytic
# Missing from GloVe: redecortaing
# Missing from GloVe: wet-suits
# Missing from GloVe: couner
# Missing from GloVe: outskate
# Missing from GloVe: stripee
# Missing from GloVe: hnight
# Missing from GloVe: resembing
# Missing from GloVe: instrument-wielding
# Missing from GloVe: umbrelllas
# Missing from GloVe: sitting3
# Missing from GloVe: trampolene
# Missing from GloVe: africam
# Missing from GloVe: entertainign
# Missing from GloVe: tampoline
# Missing from GloVe: cantunderstans
# Missing from GloVe: towgether
# Missing from GloVe: sleepinbg
# Missing from GloVe: ranbg
# Missing from GloVe: para-surf
# Missing from GloVe: leaninf
# Missing from GloVe: streeth
# Missing from GloVe: grooom
# Missing from GloVe: Specatators
# Missing from GloVe: hostaged
# Missing from GloVe: bathrobe2s
# Missing from GloVe: bevarge
# Missing from GloVe: hairstlyist
# Missing from GloVe: momosa
# Missing from GloVe: resucing
# Missing from GloVe: dancnig
# Missing from GloVe: Guggeheim
# Missing from GloVe: limo-driver
# Missing from GloVe: tallants
# Missing from GloVe: purlpe
# Missing from GloVe: conversationg
# Missing from GloVe: campfood
# Missing from GloVe: fly-fishes
# Missing from GloVe: flankie
# Missing from GloVe: floodle
# Missing from GloVe: money.t
# Missing from GloVe: jumpes
# Missing from GloVe: cow-logistics
# Missing from GloVe: cool-colored
# Missing from GloVe: malabarista
# Missing from GloVe: striped-shirt
# Missing from GloVe: onether
# Missing from GloVe: bucket-drums
# Missing from GloVe: extiguish
# Missing from GloVe: hevyset
# Missing from GloVe: cattle-drawn
# Missing from GloVe: brown-cow
# Missing from GloVe: ihuman
# Missing from GloVe: ploliceman
# Missing from GloVe: recyclales
# Missing from GloVe: serman
# Missing from GloVe: spponful
# Missing from GloVe: jackolantreen
# Missing from GloVe: watitingto
# Missing from GloVe: Bycycles
# Missing from GloVe: weegy
# Missing from GloVe: graffitid
# Missing from GloVe: ringmastering
# Missing from GloVe: performering
# Missing from GloVe: piniacolada
# Missing from GloVe: readaing
# Missing from GloVe: goat-herder
# Missing from GloVe: atadium
# Missing from GloVe: Foriengers
# Missing from GloVe: rosd
# Missing from GloVe: hysics
# Missing from GloVe: banski
# Missing from GloVe: sou-chef
# Missing from GloVe: bandans
# Missing from GloVe: tredmil
# Missing from GloVe: sovles
# Missing from GloVe: grpaes
# Missing from GloVe: susnset
# Missing from GloVe: Mowawh
# Missing from GloVe: racecare
# Missing from GloVe: vhef
# Missing from GloVe: prostestig
# Missing from GloVe: bycliclists
# Missing from GloVe: muddish
# Missing from GloVe: babrer
# Missing from GloVe: circuos
# Missing from GloVe: alonw
# Missing from GloVe: barricated
# Missing from GloVe: femla
# Missing from GloVe: jaywalks
# Missing from GloVe: prepraring
# Missing from GloVe: orangre
# Missing from GloVe: pithcer
# Missing from GloVe: volleyballteam
# Missing from GloVe: dinnder
# Missing from GloVe: twriles
# Missing from GloVe: cleaining
# Missing from GloVe: hambruger
# Missing from GloVe: texile
# Missing from GloVe: iceksating
# Missing from GloVe: adopion
# Missing from GloVe: srteet
# Missing from GloVe: botonists
# Missing from GloVe: unfording
# Missing from GloVe: piniata
# Missing from GloVe: pettign
# Missing from GloVe: powerwalkers
# Missing from GloVe: Skycraper
# Missing from GloVe: reuniuon
# Missing from GloVe: lagies
# Missing from GloVe: Hillbilies
# Missing from GloVe: pinck
# Missing from GloVe: ccurly
# Missing from GloVe: plaground
# Missing from GloVe: Carnigie
# Missing from GloVe: male-lover
# Missing from GloVe: boybis
# Missing from GloVe: Muesem
# Missing from GloVe: photogrpahers
# Missing from GloVe: nicing
# Missing from GloVe: creew
# Missing from GloVe: stufying
# Missing from GloVe: hawaaii
# Missing from GloVe: overlookes
# Missing from GloVe: fireworkers
# Missing from GloVe: Dopins
# Missing from GloVe: skateboarer
# Missing from GloVe: rhinoasarus
# Missing from GloVe: fresses
# Missing from GloVe: psoing
# Missing from GloVe: slar
# Missing from GloVe: hokeypokey
# Missing from GloVe: supporst
# Missing from GloVe: pitpull
# Missing from GloVe: jackhamer
# Missing from GloVe: temnis
# Missing from GloVe: scubadiver
# Missing from GloVe: motot
# Missing from GloVe: photpgraphers
# Missing from GloVe: outyard
# Missing from GloVe: quient
# Missing from GloVe: Rotteweiller
# Missing from GloVe: turnk
# Missing from GloVe: his/she
# Missing from GloVe: plowhorse
# Missing from GloVe: cmall
# Missing from GloVe: aclling
# Missing from GloVe: lowchair
# Missing from GloVe: helpiing
# Missing from GloVe: excorts
# Missing from GloVe: Chearleaders
# Missing from GloVe: xylaphone
# Missing from GloVe: servong
# Missing from GloVe: snowfest
# Missing from GloVe: ignroed
# Missing from GloVe: vegtebal
# Missing from GloVe: Oarange
# Missing from GloVe: routiine
# Missing from GloVe: contempates
# Missing from GloVe: growlng
# Missing from GloVe: ratign
# Missing from GloVe: sittingin
# Missing from GloVe: ecsersize
# Missing from GloVe: Ring-Around-The-Rosie
# Missing from GloVe: renessance
# Missing from GloVe: vegatbles
# Missing from GloVe: something.f
# Missing from GloVe: Severel
# Missing from GloVe: relexing
# Missing from GloVe: mcdoanalds
# Missing from GloVe: bbaby
# Missing from GloVe: somelthing
# Missing from GloVe: engagged
# Missing from GloVe: traeted
# Missing from GloVe: vacuumn
# Missing from GloVe: suicice
# Missing from GloVe: surboard
# Missing from GloVe: Surfboarders
# Missing from GloVe: lanyward
# Missing from GloVe: detists
# Missing from GloVe: pantsleg
# Missing from GloVe: whisling
# Missing from GloVe: neaqrby
# Missing from GloVe: Aperson
# Missing from GloVe: CARDING
# Missing from GloVe: Benihanas
# Missing from GloVe: sellls
# Missing from GloVe: pipe-lining
# Missing from GloVe: ahocky
# Missing from GloVe: sleeing
# Missing from GloVe: street-fair
# Missing from GloVe: roamign
# Missing from GloVe: cylcists
# Missing from GloVe: deboards
# Missing from GloVe: skyplane
# Missing from GloVe: advertiement
# Missing from GloVe: Fisbee
# Missing from GloVe: kshirt
# Missing from GloVe: Jenha
# Missing from GloVe: old-tyme
# Missing from GloVe: Completey
# Missing from GloVe: seaed
# Missing from GloVe: self-sculpture
# Missing from GloVe: childdren
# Missing from GloVe: trampoling
# Missing from GloVe: tramploine
# Missing from GloVe: autograph-hungry
# Missing from GloVe: lakehoue
# Missing from GloVe: paryy
# Missing from GloVe: happlily
# Missing from GloVe: stuits
# Missing from GloVe: Apanel
# Missing from GloVe: wookers
# Missing from GloVe: piacture
# Missing from GloVe: womanare
# Missing from GloVe: achery
# Missing from GloVe: duckhunting
# Missing from GloVe: lemonaids
# Missing from GloVe: crocheries
# Missing from GloVe: tboys
# Missing from GloVe: thelves
# Missing from GloVe: Childreans
# Missing from GloVe: compensenating
# Missing from GloVe: cocained
# Missing from GloVe: paryting
# Missing from GloVe: motorbycle
# Missing from GloVe: Wokers
# Missing from GloVe: retreaving
# Missing from GloVe: outerware
# Missing from GloVe: flisk
# Missing from GloVe: whirraging
# Missing from GloVe: carrot-apple
# Missing from GloVe: cropdusting
# Missing from GloVe: wimbleton
# Missing from GloVe: knapkins
# Missing from GloVe: wheelchair-ridden
# Missing from GloVe: ferriswheel
# Missing from GloVe: http://fresnosmilemakeovers.com/
# Missing from GloVe: Aikmen
# Missing from GloVe: erformers
# Missing from GloVe: home-cooks
# Missing from GloVe: chimnee
# Missing from GloVe: nicrophone
# Missing from GloVe: hadphones
# Missing from GloVe: attrctive
# Missing from GloVe: sheppherd
# Missing from GloVe: swinsuits
# Missing from GloVe: unarched
# Missing from GloVe: friving
# Missing from GloVe: kickstandless
# Missing from GloVe: boardward
# Missing from GloVe: ALTHELTE
# Missing from GloVe: motorcyce
# Missing from GloVe: motocyckes
# Missing from GloVe: arefun
# Missing from GloVe: coccer
# Missing from GloVe: danicing
# Missing from GloVe: werstler
# Missing from GloVe: bebcause
# Missing from GloVe: rollerskatin
# Missing from GloVe: stding
# Missing from GloVe: vesile
# Missing from GloVe: neighrborhood
# Missing from GloVe: arenea
# Missing from GloVe: clotheline
# Missing from GloVe: undwear
# Missing from GloVe: ghost-riding
# Missing from GloVe: plastix
# Missing from GloVe: FOESTED
# Missing from GloVe: somnething
# Missing from GloVe: skin-boarding
# Missing from GloVe: pants-suit
# Missing from GloVe: unicylist
# Missing from GloVe: ioutside
# Missing from GloVe: ferby
# Missing from GloVe: rolor
# Missing from GloVe: infectinon
# Missing from GloVe: girzzly
# Missing from GloVe: gentlemene
# Missing from GloVe: sewiing
# Missing from GloVe: esitting
# Missing from GloVe: wakling
# Missing from GloVe: dirtless
# Missing from GloVe: shirless
# Missing from GloVe: instrutment
# Missing from GloVe: weter
# Missing from GloVe: emprty
# Missing from GloVe: pteradactyls
# Missing from GloVe: steetcorner
# Missing from GloVe: tickiing
# Missing from GloVe: coyote-like
# Missing from GloVe: rapeling
# Missing from GloVe: giil
# Missing from GloVe: non-King
# Missing from GloVe: segulls
# Missing from GloVe: umbreallas
# Missing from GloVe: sweeeps
# Missing from GloVe: skateboRDER
# Missing from GloVe: bridsmaid
# Missing from GloVe: coconutss
# Missing from GloVe: sweathshirt
# Missing from GloVe: shiningbrightly
# Missing from GloVe: karakoe
# Missing from GloVe: grasssy
# Missing from GloVe: apprhensive
# Missing from GloVe: schduling
# Missing from GloVe: upsie
# Missing from GloVe: Com-i-con
# Missing from GloVe: wingson
# Missing from GloVe: plumetting
# Missing from GloVe: elmo-suit
# Missing from GloVe: clenliness
# Missing from GloVe: retrieveing
# Missing from GloVe: climbinga
# Missing from GloVe: busy-minded
# Missing from GloVe: getnleman
# Missing from GloVe: barrel-flower
# Missing from GloVe: Instructers
# Missing from GloVe: reaxing
# Missing from GloVe: girlsr
# Missing from GloVe: rollerskated
# Missing from GloVe: mechanci
# Missing from GloVe: black-sleeved
# Missing from GloVe: phonebooths
# Missing from GloVe: scibbles
# Missing from GloVe: catq
# Missing from GloVe: OTwo
# Missing from GloVe: outsside
# Missing from GloVe: asoccer
# Missing from GloVe: Pedestriatians
# Missing from GloVe: guital
# Missing from GloVe: balons
# Missing from GloVe: Childrend
# Missing from GloVe: squeezd
# Missing from GloVe: snowboardint
# Missing from GloVe: banmates
# Missing from GloVe: Lifegaurds
# Missing from GloVe: beareded
# Missing from GloVe: pedestrian-free
# Missing from GloVe: bridge-hopping
# Missing from GloVe: straning
# Missing from GloVe: advertistment
# Missing from GloVe: adverisment
# Missing from GloVe: skatebaoard
# Missing from GloVe: entrepernuer
# Missing from GloVe: rappells
# Missing from GloVe: embrases
# Missing from GloVe: festivle
# Missing from GloVe: rotary-club
# Missing from GloVe: highjumper
# Missing from GloVe: grcoery
# Missing from GloVe: mwas
# Missing from GloVe: palaminos
# Missing from GloVe: surf-skiing
# Missing from GloVe: surf-skiier
# Missing from GloVe: bare-walled
# Missing from GloVe: tounry
# Missing from GloVe: shydrivers
# Missing from GloVe: greoup
# Missing from GloVe: solicitating
# Missing from GloVe: randsom
# Missing from GloVe: roughcourse
# Missing from GloVe: patroles
# Missing from GloVe: biue
# Missing from GloVe: isdriving
# Missing from GloVe: fpeople
# Missing from GloVe: olympcs
# Missing from GloVe: beacbh
# Missing from GloVe: floer
# Missing from GloVe: slolum
# Missing from GloVe: vistings
# Missing from GloVe: rivial
# Missing from GloVe: dire-need
# Missing from GloVe: untouching
# Missing from GloVe: paitinging
# Missing from GloVe: clarenet
# Missing from GloVe: sperlunking
# Missing from GloVe: artifacts/objects
# Missing from GloVe: inddors
# Missing from GloVe: cemenet
# Missing from GloVe: puttputt
# Missing from GloVe: Awoman
# Missing from GloVe: cooat
# Missing from GloVe: scocer
# Missing from GloVe: solitutde
# Missing from GloVe: constructionsite
# Missing from GloVe: belonings
# Missing from GloVe: esacaped
# Missing from GloVe: silhouetter
# Missing from GloVe: Blue-clad
# Missing from GloVe: melonless
# Missing from GloVe: rescue-dogs
# Missing from GloVe: womenplay
# Missing from GloVe: mallwalkers
# Missing from GloVe: SuV
# Missing from GloVe: dominp
# Missing from GloVe: rehitting
# Missing from GloVe: SpiderMen
# Missing from GloVe: reshingles
# Missing from GloVe: mountain-climbers
# Missing from GloVe: atanding
# Missing from GloVe: tangeled
# Missing from GloVe: convnersation
# Missing from GloVe: nObody
# Missing from GloVe: artifcast
# Missing from GloVe: gunglasses
# Missing from GloVe: reclinedon
# Missing from GloVe: astronuants
# Missing from GloVe: casual-ware
# Missing from GloVe: trumpeteers
# Missing from GloVe: stannding
# Missing from GloVe: ammusement
# Missing from GloVe: dnad
# Missing from GloVe: tollder
# Missing from GloVe: whiste
# Missing from GloVe: stadum
# Missing from GloVe: hairl
# Missing from GloVe: attennding
# Missing from GloVe: competining
# Missing from GloVe: skate-boarder
# Missing from GloVe: orane
# Missing from GloVe: roadi
# Missing from GloVe: skateboading
# Missing from GloVe: refriderators
# Missing from GloVe: womanin
# Missing from GloVe: photogropher
# Missing from GloVe: zooworker
# Missing from GloVe: midicine
# Missing from GloVe: for32
# Missing from GloVe: flower-girls
# Missing from GloVe: hay-filled
# Missing from GloVe: multch
# Missing from GloVe: sptting
# Missing from GloVe: negioating
# Missing from GloVe: x-sports
# Missing from GloVe: FOurth
# Missing from GloVe: tramploline
# Missing from GloVe: enjyoing
# Missing from GloVe: dogwas
# Missing from GloVe: spretzels
# Missing from GloVe: reheases
# Missing from GloVe: doggie-paddles
# Missing from GloVe: tlaks
# Missing from GloVe: Adidas-sponsored
# Missing from GloVe: banf
# Missing from GloVe: congretation
# Missing from GloVe: farm-oriented
# Missing from GloVe: handinglout
# Missing from GloVe: clownsuit
# Missing from GloVe: muscisian
# Missing from GloVe: bycycles
# Missing from GloVe: triorchidism
# Missing from GloVe: cyclinsts
# Missing from GloVe: Thepeople
# Missing from GloVe: Thewoman
# Missing from GloVe: kirl
# Missing from GloVe: out-dunked
# Missing from GloVe: walkiing
# Missing from GloVe: underwate
# Missing from GloVe: fishremans
# Missing from GloVe: rushohour
# Missing from GloVe: kniiting
# Missing from GloVe: Cro-magnons
# Missing from GloVe: wetsuit.
# Missing from GloVe: teaaching
# Missing from GloVe: bellyrub
# Missing from GloVe: highths
# Missing from GloVe: goldenretriever
# Missing from GloVe: Bi-cycle
# Missing from GloVe: chilfren
# Missing from GloVe: ice-fish
# Missing from GloVe: rockclimb
# Loading GloVe
# Total number of null word embeddings:
# 4043

# %%
rnn_kwargs = dict(output_dim=SENT_HIDDEN_SIZE, dropout_W=DP, dropout_U=DP)
SumEmbeddings = keras.layers.core.Lambda(lambda x: K.sum(x, axis=1), output_shape=(SENT_HIDDEN_SIZE, ))

translate = TimeDistributed(Dense(SENT_HIDDEN_SIZE, activation=ACTIVATION))

premise = Input(shape=(MAX_LEN,), dtype='int32')
hypothesis = Input(shape=(MAX_LEN,), dtype='int32')

prem = embed(premise)
hypo = embed(hypothesis)

prem = translate(prem)
hypo = translate(hypo)

if RNN and LAYERS > 1:
  for l in range(LAYERS - 1):
    rnn = RNN(return_sequences=True, **rnn_kwargs)
    prem = BatchNormalization()(rnn(prem))
    hypo = BatchNormalization()(rnn(hypo))
rnn = SumEmbeddings if not RNN else RNN(return_sequences=False, **rnn_kwargs)
prem = rnn(prem)
hypo = rnn(hypo)
prem = BatchNormalization()(prem)
hypo = BatchNormalization()(hypo)

joint = concatenate([prem, hypo])
joint = Dropout(DP)(joint)
for i in range(3):
  joint = Dense(2 * SENT_HIDDEN_SIZE, activation=ACTIVATION)(joint)
  joint = Dropout(DP)(joint)
  joint = BatchNormalization()(joint)

pred = Dense(len(LABELS), activation='softmax')(joint)

model = Model(inputs=[premise, hypothesis], outputs=pred)
model.compile(optimizer=OPTIMIZER, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()

print('Training')
_, tmpfn = tempfile.mkstemp()
# Save the best model during validation and bail out of training early if we're not improving
callbacks = [EarlyStopping(patience=PATIENCE), ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)]
model.fit([training[0], training[1]], training[2], batch_size=BATCH_SIZE, epochs=MAX_EPOCHS, validation_split=0.3)#validation_data=([validation[0], validation[1]], validation[2]), callbacks=callbacks)

# Restore the best found model during validation
model.load_weights(tmpfn)

loss, acc = model.evaluate([test[0], test[1]], test[2], batch_size=BATCH_SIZE)
print('Test loss / test accuracy = {:.4f} / {:.4f}'.format(loss, acc))
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 42)]         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 42)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 42, 300)      12717300    input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 42, 300)      90300       embedding[2][0]
#                                                                  embedding[3][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 300)          0           time_distributed_1[0][0]
#                                                                  time_distributed_1[1][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 300)          1200        lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 300)          1200        lambda_1[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 600)          0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 600)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 600)          360600      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 600)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 600)          2400        dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 600)          360600      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 600)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 600)          2400        dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 600)          360600      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 600)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 600)          2400        dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 3)            1803        batch_normalization_9[0][0]
# ==================================================================================================
# Total params: 13,900,803
# Trainable params: 1,178,703
# Non-trainable params: 12,722,100
# __________________________________________________________________________________________________
# Training
# Epoch 1/42
# 752/752 [==============================] - 22s 27ms/step - loss: 1.0092 - accuracy: 0.5693 - val_loss: 0.7175 - val_accuracy: 0.6936
# Epoch 2/42
# 752/752 [==============================] - 20s 26ms/step - loss: 0.6645 - accuracy: 0.7209 - val_loss: 0.6586 - val_accuracy: 0.7234
# Epoch 3/42
# 438/752 [================>.............] - ETA: 6s - loss: 0.6076 - accuracy: 0.7487
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-8bb6e43a50fa> in <module>()
#      42 # Save the best model during validation and bail out of training early if we're not improving
#      43 callbacks = [EarlyStopping(patience=PATIENCE), ModelCheckpoint(tmpfn, save_best_only=True, save_weights_only=True)]
# ---> 44 model.fit([training[0], training[1]], training[2], batch_size=BATCH_SIZE, epochs=MAX_EPOCHS, validation_split=0.3)#validation_data=([validation[0], validation[1]], validation[2]), callbacks=callbacks)
#      45
#      46 # Restore the best found model during validation
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1105               callbacks.on_train_batch_end(end_step, logs)
#    1106               if self.stop_training:
# -> 1107                 break
#    1108
#    1109         if logs is None:
#
# KeyboardInterrupt:
